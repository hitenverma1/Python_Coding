# %%
# !pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-2.13.0-py2.py3-none-any.whl (14.0 MB)
#      --------------------------------------- 14.0/14.0 MB 10.4 MB/s eta 0:00:00
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
#      ---------------------------------------- 65.9/65.9 MB 9.2 MB/s eta 0:00:00
# Collecting strsimpy
#   Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#      ---------------------------------------- 45.9/45.9 kB ? eta 0:00:00
# Requirement already satisfied: Flask in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (2.2.2)
# Requirement already satisfied: future>=0.14.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (0.18.2)
# Requirement already satisfied: xlrd in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: cycler in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (0.11.0)
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: et-xmlfile in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: requests in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (2.28.1)
# Requirement already satisfied: itsdangerous in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (2.1.2)
# Collecting dash-colorscales
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#      ---------------------------------------- 62.3/62.3 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: openpyxl!=3.2.0b1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (3.0.10)
# Requirement already satisfied: matplotlib<=3.6.3 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (3.6.2)
# Collecting scipy==1.9.3
#   Downloading scipy-1.9.3-cp310-cp310-win_amd64.whl (40.1 MB)
#      ---------------------------------------- 40.1/40.1 MB 9.9 MB/s eta 0:00:00
# Collecting missingno<=0.4.2
#   Downloading missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Collecting dash-bootstrap-components<=1.3.1
#   Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl (219 kB)
#      ------------------------------------- 219.7/219.7 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (1.1.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (4.11.1)
# Requirement already satisfied: seaborn in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (0.12.1)
# Collecting Flask-Compress
#   Downloading Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: six in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (1.16.0)
# Collecting dash>=2.0.0
#   Downloading dash-2.9.2-py3-none-any.whl (10.2 MB)
#      --------------------------------------- 10.2/10.2 MB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (1.23.0)
# Collecting dash-daq
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ------------------------------------- 642.7/642.7 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: statsmodels in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (0.13.5)
# Requirement already satisfied: certifi in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (2022.6.15)
# Requirement already satisfied: pandas in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (1.4.3)
# Requirement already satisfied: networkx in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (2.8.4)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from dtale) (5.12.0)
# Collecting lz4
#   Downloading lz4-4.3.2-cp310-cp310-win_amd64.whl (99 kB)
#      ---------------------------------------- 99.8/99.8 kB ? eta 0:00:00
# Collecting xarray
#   Downloading xarray-2023.3.0-py3-none-any.whl (981 kB)
#      ------------------------------------- 981.2/981.2 kB 12.4 MB/s eta 0:00:00
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from Flask->dtale) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from Flask->dtale) (3.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from Flask->dtale) (8.1.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.6.3->dtale) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.6.3->dtale) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.6.3->dtale) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.6.3->dtale) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.6.3->dtale) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.6.3->dtale) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.6.3->dtale) (1.4.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from plotly>=5.0.0->dtale) (8.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->dtale) (2.3.2.post1)
# Requirement already satisfied: brotli in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from pandas->dtale) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from requests->dtale) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from requests->dtale) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from requests->dtale) (1.26.10)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->dtale) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->dtale) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from statsmodels->dtale) (0.5.3)
# Requirement already satisfied: colorama in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from click>=8.0->Flask->dtale) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.0->Flask->dtale) (2.1.1)
# Installing collected packages: strsimpy, squarify, kaleido, dash-table, dash-html-components, dash-core-components, dash-colorscales, scipy, lz4, xarray, flask-ngrok, Flask-Compress, dash, missingno, dash-daq, dash-bootstrap-components, dtale
#   Running setup.py install for dash-colorscales: started
#   Running setup.py install for dash-colorscales: finished with status 'done'
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.8.1
#     Uninstalling scipy-1.8.1:
#       Successfully uninstalled scipy-1.8.1
#   Running setup.py install for dash-daq: started
#   Running setup.py install for dash-daq: finished with status 'done'
# Successfully installed Flask-Compress-1.13 dash-2.9.2 dash-bootstrap-components-1.3.1 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-2.13.0 flask-ngrok-0.0.25 kaleido-0.2.1 lz4-4.3.2 missingno-0.4.2 scipy-1.9.3 squarify-0.4.3 strsimpy-0.2.1 xarray-2023.3.0
#   DEPRECATION: dash-colorscales is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: dash-daq is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559

# %%
import pandas as pd
import dtale

# import dtale.app as dtale_app
# dtale_app.USE_COLAB = True

# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dtale.show(df)
# Out:
# c:\Users\hiten\AppData\Local\Programs\Python\Python310\lib\site-packages\dtale\views.py:755: FutureWarning:
#
# ['embarked', 'class', 'deck', 'embark_town'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-31TCK1O:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
