# %%
# !pip install autoviz
# Out:
# Collecting autoviz
#   Using cached autoviz-0.1.58-py3-none-any.whl (64 kB)
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (3.7)
# Requirement already satisfied: statsmodels in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (0.13.5)
# Collecting emoji
#   Using cached emoji-2.2.0.tar.gz (240 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ipython in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (8.4.0)
# Collecting pyamg
#   Using cached pyamg-4.2.3-cp310-cp310-win_amd64.whl (1.4 MB)
# Requirement already satisfied: matplotlib>=3.3.3 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (3.6.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (4.5.0)
# Requirement already satisfied: numpy in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (1.23.0)
# Requirement already satisfied: seaborn>=0.11.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (0.12.1)
# Requirement already satisfied: scikit-learn in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (1.1.3)
# Collecting bokeh>=2.4.2
#   Using cached bokeh-3.1.0-py3-none-any.whl (8.3 MB)
# Collecting panel~=0.12.6
#   Using cached panel-0.12.7-py2.py3-none-any.whl (12.9 MB)
# Requirement already satisfied: xlrd in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (2.0.1)
# Collecting wordcloud
#   Using cached wordcloud-1.8.2.2-cp310-cp310-win_amd64.whl (153 kB)
# Requirement already satisfied: pandas in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (1.4.3)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from autoviz) (2022.11.0)
# Collecting hvplot>=0.7.3
#   Using cached hvplot-0.8.3-py2.py3-none-any.whl (3.2 MB)
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting xgboost>=0.82
#   Using cached xgboost-1.7.5-py3-none-win_amd64.whl (70.9 MB)
# Collecting holoviews>=1.14.6
#   Using cached holoviews-1.15.4-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: packaging>=16.8 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from bokeh>=2.4.2->autoviz) (21.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from bokeh>=2.4.2->autoviz) (3.1.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from bokeh>=2.4.2->autoviz) (6.2)
# Requirement already satisfied: contourpy>=1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from bokeh>=2.4.2->autoviz) (1.0.6)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from bokeh>=2.4.2->autoviz) (9.2.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from bokeh>=2.4.2->autoviz) (5.4.1)
# Collecting xyzservices>=2021.09.1
#   Using cached xyzservices-2023.2.0-py3-none-any.whl (55 kB)
# Collecting param<2.0,>=1.9.3
#   Using cached param-1.13.0-py2.py3-none-any.whl (87 kB)
# Collecting colorcet
#   Using cached colorcet-3.0.1-py2.py3-none-any.whl (1.7 MB)
# Collecting pyviz-comms>=0.7.4
#   Using cached pyviz_comms-2.2.1-py2.py3-none-any.whl (42 kB)
# Collecting holoviews>=1.14.6
#   Using cached holoviews-1.15.3-py2.py3-none-any.whl (4.3 MB)
#   Using cached holoviews-1.15.2-py2.py3-none-any.whl (4.3 MB)
#   Using cached holoviews-1.15.1-py2.py3-none-any.whl (4.3 MB)
#   Using cached holoviews-1.15.0-py2.py3-none-any.whl (4.3 MB)
#   Using cached holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->autoviz) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->autoviz) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->autoviz) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->autoviz) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from pandas->autoviz) (2022.1)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from panel~=0.12.6->autoviz) (4.64.0)
# Requirement already satisfied: setuptools<61,>=42 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from panel~=0.12.6->autoviz) (58.1.0)
# Requirement already satisfied: requests in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from panel~=0.12.6->autoviz) (2.28.1)
# Collecting pyct>=0.4.4
#   Using cached pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Collecting markdown
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting bokeh>=2.4.2
#   Using cached bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Collecting bleach
#   Using cached bleach-6.0.0-py3-none-any.whl (162 kB)
# Requirement already satisfied: scipy in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from xgboost>=0.82->autoviz) (1.8.1)
# Requirement already satisfied: stack-data in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (0.3.0)
# Requirement already satisfied: matplotlib-inline in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (3.0.30)
# Requirement already satisfied: pickleshare in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (2.12.0)
# Requirement already satisfied: colorama in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (0.4.4)
# Requirement already satisfied: traitlets>=5 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (5.9.0)
# Requirement already satisfied: backcall in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipython->autoviz) (0.18.1)
# Collecting nbconvert
#   Using cached nbconvert-7.2.10-py3-none-any.whl (275 kB)
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.0.6-py3-none-any.whl (138 kB)
# Collecting qtconsole
#   Using cached qtconsole-5.4.1-py3-none-any.whl (120 kB)
# Collecting notebook
#   Using cached notebook-6.5.3-py3-none-any.whl (529 kB)
# Requirement already satisfied: ipykernel in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jupyter->autoviz) (6.15.1)
# Requirement already satisfied: joblib in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from nltk->autoviz) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from nltk->autoviz) (2022.10.31)
# Requirement already satisfied: click in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from nltk->autoviz) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->autoviz) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from statsmodels->autoviz) (0.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->autoviz) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.9->bokeh>=2.4.2->autoviz) (2.1.1)
# Requirement already satisfied: six in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from patsy>=0.5.2->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz) (0.2.5)
# Requirement already satisfied: webencodings in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from bleach->panel~=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: psutil in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->autoviz) (5.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->autoviz) (7.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->autoviz) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->autoviz) (1.6.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->autoviz) (25.0.2)
# Collecting jupyterlab-widgets~=3.0.7
#   Using cached jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter->autoviz) (4.0.7)
# Collecting jupyter-core!=5.0.*,>=4.12
#   Using cached jupyter_core-5.3.0-py3-none-any.whl (93 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting nbformat>=5.1
#   Using cached nbformat-5.8.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: tinycss2 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->autoviz) (1.2.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->autoviz) (2.0.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->autoviz) (4.11.1)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.7.2-py3-none-any.whl (71 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.16.0-py3-none-any.whl (122 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: ipython-genutils in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter->autoviz) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Collecting nbclassic>=0.4.7
#   Using cached nbclassic-0.5.4-py3-none-any.whl (10.0 MB)
# Collecting qtpy>=2.0.1
#   Using cached QtPy-2.3.1-py3-none-any.whl (84 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from requests->panel~=0.12.6->autoviz) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from requests->panel~=0.12.6->autoviz) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from requests->panel~=0.12.6->autoviz) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from requests->panel~=0.12.6->autoviz) (1.26.10)
# Requirement already satisfied: asttokens in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->autoviz) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->autoviz) (0.2.2)
# Requirement already satisfied: executing in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->autoviz) (0.9.1)
# Requirement already satisfied: entrypoints in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->autoviz) (0.4)
# Requirement already satisfied: pywin32>=300 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->autoviz) (304)
# Collecting platformdirs>=2.5
#   Using cached platformdirs-3.2.0-py3-none-any.whl (14 kB)
# Collecting notebook-shim>=0.1.0
#   Using cached notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting jupyter-server>=1.8
#   Using cached jupyter_server-2.5.0-py3-none-any.whl (366 kB)
# Collecting jsonschema>=2.6
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Requirement already satisfied: fastjsonschema in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz) (2.16.3)
# Collecting pywinpty>=1.1.0
#   Using cached pywinpty-2.0.10-cp310-none-win_amd64.whl (1.4 MB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz) (2.3.2.post1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (22.1.0)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Using cached pyrsistent-0.19.3-cp310-cp310-win_amd64.whl (62 kB)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (3.6.1)
# Collecting jupyter-client>=6.1.12
#   Using cached jupyter_client-8.1.0-py3-none-any.whl (102 kB)
# Collecting jupyter-events>=0.4.0
#   Using cached jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: websocket-client in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (1.5.1)
# Collecting jupyter-server-terminals
#   Using cached jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (2.21)
# Requirement already satisfied: rfc3339-validator in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.1.4)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.1.1)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: webcolors>=1.11 in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (1.13)
# Requirement already satisfied: uri-template in c:\users\hiten\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (1.2.0)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Installing collected packages: pywinpty, python-json-logger, pyrsistent, prometheus-client, platformdirs, param, pandocfilters, markdown, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, fqdn, emoji, defusedxml, bleach, xgboost, terminado, qtpy, pyviz-comms, pyct, pyamg, jupyter-core, jsonschema, bokeh, arrow, argon2-cffi-bindings, wordcloud, textblob, panel, nbformat, jupyter-server-terminals, jupyter-client, isoduration, colorcet, argon2-cffi, nbclient, holoviews, qtconsole, nbconvert, jupyter-events, jupyter-console, ipywidgets, hvplot, jupyter-server, notebook-shim, nbclassic, notebook, jupyter, autoviz
#   Running setup.py install for emoji: started
#   Running setup.py install for emoji: finished with status 'done'
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.11.1
#     Uninstalling jupyter-core-4.11.1:
#       Successfully uninstalled jupyter-core-4.11.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 7.3.4
#     Uninstalling jupyter-client-7.3.4:
#       Successfully uninstalled jupyter-client-7.3.4
# Successfully installed argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 autoviz-0.1.58 bleach-6.0.0 bokeh-2.4.3 colorcet-3.0.1 defusedxml-0.7.1 emoji-2.2.0 fqdn-1.5.1 holoviews-1.14.9 hvplot-0.8.3 ipywidgets-8.0.6 isoduration-20.11.0 jsonpointer-2.3 jsonschema-4.17.3 jupyter-1.0.0 jupyter-client-8.1.0 jupyter-console-6.6.3 jupyter-core-5.3.0 jupyter-events-0.6.3 jupyter-server-2.5.0 jupyter-server-terminals-0.4.4 jupyterlab-pygments-0.2.2 jupyterlab-widgets-3.0.7 markdown-3.4.3 nbclassic-0.5.4 nbclient-0.7.2 nbconvert-7.2.10 nbformat-5.8.0 notebook-6.5.3 notebook-shim-0.2.2 pandocfilters-1.5.0 panel-0.12.7 param-1.13.0 platformdirs-3.2.0 prometheus-client-0.16.0 pyamg-4.2.3 pyct-0.5.0 pyrsistent-0.19.3 python-json-logger-2.0.7 pyviz-comms-2.2.1 pywinpty-2.0.10 qtconsole-5.4.1 qtpy-2.3.1 terminado-0.17.1 textblob-0.17.1 wordcloud-1.8.2.2 xgboost-1.7.5
#   DEPRECATION: emoji is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.to_csv('tips.csv')

# %%
# !pip install autoviz
# Out:
# Collecting autoviz
#   Using cached autoviz-0.1.58-py3-none-any.whl (64 kB)
# Requirement already satisfied: numpy in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (1.21.5)
# Requirement already satisfied: seaborn>=0.11.1 in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (0.11.2)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (2022.2.0)
# Requirement already satisfied: holoviews>=1.14.6 in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (1.14.8)
# Collecting emoji
#   Using cached emoji-2.2.0.tar.gz (240 kB)
# Requirement already satisfied: nltk in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (3.7)
# Collecting panel~=0.12.6
#   Using cached panel-0.12.7-py2.py3-none-any.whl (12.9 MB)
# Collecting xgboost>=0.82
#   Using cached xgboost-1.7.5-py3-none-win_amd64.whl (70.9 MB)
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: bokeh>=2.4.2 in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (2.4.2)
# Requirement already satisfied: hvplot>=0.7.3 in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (0.7.3)
# Requirement already satisfied: matplotlib>=3.3.3 in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (3.5.1)
# Requirement already satisfied: scikit-learn in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (1.0.2)
# Requirement already satisfied: xlrd in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (2.0.1)
# Requirement already satisfied: jupyter in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (1.0.0)
# Requirement already satisfied: ipython in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (8.2.0)
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: pandas in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (1.4.2)
# Requirement already satisfied: statsmodels in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\hiten\anaconda3\lib\site-packages (from autoviz) (4.1.1)
# Collecting pyamg
#   Downloading pyamg-4.2.3-cp39-cp39-win_amd64.whl (1.4 MB)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\hiten\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (9.0.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\hiten\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (2.11.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\hiten\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\hiten\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (6.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\hiten\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (21.3)
# Requirement already satisfied: param<2.0,>=1.9.3 in c:\users\hiten\anaconda3\lib\site-packages (from holoviews>=1.14.6->autoviz) (1.12.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\hiten\anaconda3\lib\site-packages (from holoviews>=1.14.6->autoviz) (2.0.2)
# Requirement already satisfied: colorcet in c:\users\hiten\anaconda3\lib\site-packages (from holoviews>=1.14.6->autoviz) (2.0.6)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\hiten\anaconda3\lib\site-packages (from colorcet->holoviews>=1.14.6->autoviz) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hiten\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=2.4.2->autoviz) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hiten\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (0.11.0)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hiten\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hiten\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hiten\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hiten\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hiten\anaconda3\lib\site-packages (from pandas->autoviz) (2021.3)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\hiten\anaconda3\lib\site-packages (from panel~=0.12.6->autoviz) (4.64.0)
# Requirement already satisfied: requests in c:\users\hiten\anaconda3\lib\site-packages (from panel~=0.12.6->autoviz) (2.27.1)
# Requirement already satisfied: markdown in c:\users\hiten\anaconda3\lib\site-packages (from panel~=0.12.6->autoviz) (3.3.4)
# Requirement already satisfied: bleach in c:\users\hiten\anaconda3\lib\site-packages (from panel~=0.12.6->autoviz) (4.1.0)
# Collecting setuptools<61,>=42
#   Downloading setuptools-60.10.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: six>=1.5 in c:\users\hiten\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->autoviz) (1.16.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\hiten\anaconda3\lib\site-packages (from seaborn>=0.11.1->autoviz) (1.7.3)
# Requirement already satisfied: colorama in c:\users\hiten\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel~=0.12.6->autoviz) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\hiten\anaconda3\lib\site-packages (from bleach->panel~=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\hiten\anaconda3\lib\site-packages (from ipython->autoviz) (3.0.20)
# Requirement already satisfied: stack-data in c:\users\hiten\anaconda3\lib\site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: backcall in c:\users\hiten\anaconda3\lib\site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hiten\anaconda3\lib\site-packages (from ipython->autoviz) (2.11.2)
# Requirement already satisfied: traitlets>=5 in c:\users\hiten\anaconda3\lib\site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: decorator in c:\users\hiten\anaconda3\lib\site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hiten\anaconda3\lib\site-packages (from ipython->autoviz) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hiten\anaconda3\lib\site-packages (from ipython->autoviz) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\hiten\anaconda3\lib\site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hiten\anaconda3\lib\site-packages (from jedi>=0.16->ipython->autoviz) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\hiten\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz) (0.2.5)
# Requirement already satisfied: ipywidgets in c:\users\hiten\anaconda3\lib\site-packages (from jupyter->autoviz) (7.6.5)
# Requirement already satisfied: jupyter-console in c:\users\hiten\anaconda3\lib\site-packages (from jupyter->autoviz) (6.4.0)
# Requirement already satisfied: qtconsole in c:\users\hiten\anaconda3\lib\site-packages (from jupyter->autoviz) (5.3.0)
# Requirement already satisfied: notebook in c:\users\hiten\anaconda3\lib\site-packages (from jupyter->autoviz) (6.4.8)
# Requirement already satisfied: ipykernel in c:\users\hiten\anaconda3\lib\site-packages (from jupyter->autoviz) (6.9.1)
# Requirement already satisfied: nbconvert in c:\users\hiten\anaconda3\lib\site-packages (from jupyter->autoviz) (6.4.4)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\hiten\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\users\hiten\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\hiten\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (1.5.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\hiten\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\hiten\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hiten\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter->autoviz) (302)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hiten\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hiten\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\hiten\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\hiten\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (0.2.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\hiten\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\hiten\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hiten\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hiten\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (0.18.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hiten\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hiten\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\hiten\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\hiten\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hiten\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->autoviz) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hiten\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->autoviz) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hiten\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\hiten\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (2.21)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hiten\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hiten\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\hiten\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\hiten\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (4.11.1)
# Requirement already satisfied: testpath in c:\users\hiten\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\hiten\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hiten\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hiten\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (1.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hiten\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz) (2.3.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hiten\anaconda3\lib\site-packages (from nltk->autoviz) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\hiten\anaconda3\lib\site-packages (from nltk->autoviz) (1.1.0)
# Requirement already satisfied: click in c:\users\hiten\anaconda3\lib\site-packages (from nltk->autoviz) (8.0.4)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\hiten\anaconda3\lib\site-packages (from qtconsole->jupyter->autoviz) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hiten\anaconda3\lib\site-packages (from requests->panel~=0.12.6->autoviz) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hiten\anaconda3\lib\site-packages (from requests->panel~=0.12.6->autoviz) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hiten\anaconda3\lib\site-packages (from requests->panel~=0.12.6->autoviz) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hiten\anaconda3\lib\site-packages (from requests->panel~=0.12.6->autoviz) (2022.6.15)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hiten\anaconda3\lib\site-packages (from scikit-learn->autoviz) (2.2.0)
# Requirement already satisfied: pure-eval in c:\users\hiten\anaconda3\lib\site-packages (from stack-data->ipython->autoviz) (0.2.2)
# Requirement already satisfied: executing in c:\users\hiten\anaconda3\lib\site-packages (from stack-data->ipython->autoviz) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hiten\anaconda3\lib\site-packages (from stack-data->ipython->autoviz) (2.0.5)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\hiten\anaconda3\lib\site-packages (from statsmodels->autoviz) (0.5.2)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234927 sha256=b2ea4f2951678ecbdd385a3d3dd9d1c53c85b2be49efaaeb64194417dc237d1b
#   Stored in directory: c:\users\hiten\appdata\local\pip\cache\wheels\9a\b8\0f\f580817231cbf59f6ade9fd132ff60ada1de9f7dc85521f857
# Successfully built emoji
# Installing collected packages: setuptools, panel, xgboost, wordcloud, textblob, pyamg, emoji, autoviz
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 61.2.0
#     Uninstalling setuptools-61.2.0:
#       Successfully uninstalled setuptools-61.2.0
#   Attempting uninstall: panel
#     Found existing installation: panel 0.13.0
#     Uninstalling panel-0.13.0:
#       Successfully uninstalled panel-0.13.0
# Successfully installed autoviz-0.1.58 emoji-2.2.0 panel-0.12.7 pyamg-4.2.3 setuptools-60.10.0 textblob-0.17.1 wordcloud-1.8.2.2 xgboost-1.7.5

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename = "tips.csv"

dft = AV.AutoViz(
    filename
)
# Out:
# Shape of your Data Set loaded: (244, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_992fc_row0_col0, #T_992fc_row0_col4, #T_992fc_row6_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_992fc_row0_col1, #T_992fc_row0_col6, #T_992fc_row1_col1, #T_992fc_row1_col6, #T_992fc_row2_col1, #T_992fc_row2_col6, #T_992fc_row3_col1, #T_992fc_row3_col6, #T_992fc_row4_col1, #T_992fc_row4_col6, #T_992fc_row5_col1, #T_992fc_row5_col6, #T_992fc_row6_col1, #T_992fc_row6_col6, #T_992fc_row7_col1, #T_992fc_row7_col6 {
#   font-family: Segoe UI;
# }
# #T_992fc_row0_col2, #T_992fc_row0_col3, #T_992fc_row0_col5, #T_992fc_row1_col2, #T_992fc_row1_col3, #T_992fc_row1_col5, #T_992fc_row2_col2, #T_992fc_row2_col3, #T_992fc_row2_col5, #T_992fc_row3_col2, #T_992fc_row3_col3, #T_992fc_row3_col5, #T_992fc_row4_col2, #T_992fc_row4_col3, #T_992fc_row5_col0, #T_992fc_row5_col2, #T_992fc_row5_col3, #T_992fc_row5_col4, #T_992fc_row6_col0, #T_992fc_row6_col2, #T_992fc_row6_col3, #T_992fc_row6_col4, #T_992fc_row7_col0, #T_992fc_row7_col2, #T_992fc_row7_col3, #T_992fc_row7_col4 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_992fc_row1_col0, #T_992fc_row1_col4 {
#   background-color: #840711;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_992fc_row2_col0 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_992fc_row2_col4 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_992fc_row3_col0, #T_992fc_row3_col4 {
#   background-color: #fff2ec;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_992fc_row4_col0, #T_992fc_row4_col4 {
#   background-color: #fff4ee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_992fc_row4_col5 {
#   background-color: #fdc9b3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_992fc_row5_col5 {
#   background-color: #860811;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_992fc_row7_col5 {
#   background-color: #d01d1f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_992fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_992fc_level0_col0" class="col_heading level0 col0" >Nuniques</th>
#       <th id="T_992fc_level0_col1" class="col_heading level0 col1" >dtype</th>
#       <th id="T_992fc_level0_col2" class="col_heading level0 col2" >Nulls</th>
#       <th id="T_992fc_level0_col3" class="col_heading level0 col3" >Nullpercent</th>
#       <th id="T_992fc_level0_col4" class="col_heading level0 col4" >NuniquePercent</th>
#       <th id="T_992fc_level0_col5" class="col_heading level0 col5" >Value counts Min</th>
#       <th id="T_992fc_level0_col6" class="col_heading level0 col6" >Data cleaning improvement suggestions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_992fc_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_992fc_row0_col0" class="data row0 col0" >244</td>
#       <td id="T_992fc_row0_col1" class="data row0 col1" >int64</td>
#       <td id="T_992fc_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_992fc_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_992fc_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_992fc_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_992fc_row0_col6" class="data row0 col6" >possible ID column: drop</td>
#     </tr>
#     <tr>
#       <th id="T_992fc_level0_row1" class="row_heading level0 row1" >total_bill</th>
#       <td id="T_992fc_row1_col0" class="data row1 col0" >229</td>
#       <td id="T_992fc_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_992fc_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_992fc_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_992fc_row1_col4" class="data row1 col4" >93.852459</td>
#       <td id="T_992fc_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_992fc_row1_col6" class="data row1 col6" >skewed: cap or drop outliers</td>
#     </tr>
#     <tr>
#       <th id="T_992fc_level0_row2" class="row_heading level0 row2" >tip</th>
#       <td id="T_992fc_row2_col0" class="data row2 col0" >123</td>
#       <td id="T_992fc_row2_col1" class="data row2 col1" >float64</td>
#       <td id="T_992fc_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_992fc_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_992fc_row2_col4" class="data row2 col4" >50.409836</td>
#       <td id="T_992fc_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_992fc_row2_col6" class="data row2 col6" >skewed: cap or drop outliers</td>
#     </tr>
#     <tr>
#       <th id="T_992fc_level0_row3" class="row_heading level0 row3" >size</th>
#       <td id="T_992fc_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_992fc_row3_col1" class="data row3 col1" >int64</td>
#       <td id="T_992fc_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_992fc_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_992fc_row3_col4" class="data row3 col4" >2.459016</td>
#       <td id="T_992fc_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_992fc_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_992fc_level0_row4" class="row_heading level0 row4" >day</th>
#       <td id="T_992fc_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_992fc_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_992fc_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_992fc_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_992fc_row4_col4" class="data row4 col4" >1.639344</td>
#       <td id="T_992fc_row4_col5" class="data row4 col5" >19</td>
#       <td id="T_992fc_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_992fc_level0_row5" class="row_heading level0 row5" >sex</th>
#       <td id="T_992fc_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_992fc_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_992fc_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_992fc_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_992fc_row5_col4" class="data row5 col4" >0.819672</td>
#       <td id="T_992fc_row5_col5" class="data row5 col5" >87</td>
#       <td id="T_992fc_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_992fc_level0_row6" class="row_heading level0 row6" >smoker</th>
#       <td id="T_992fc_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_992fc_row6_col1" class="data row6 col1" >object</td>
#       <td id="T_992fc_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_992fc_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_992fc_row6_col4" class="data row6 col4" >0.819672</td>
#       <td id="T_992fc_row6_col5" class="data row6 col5" >93</td>
#       <td id="T_992fc_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_992fc_level0_row7" class="row_heading level0 row7" >time</th>
#       <td id="T_992fc_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_992fc_row7_col1" class="data row7 col1" >object</td>
#       <td id="T_992fc_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_992fc_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_992fc_row7_col4" class="data row7 col4" >0.819672</td>
#       <td id="T_992fc_row7_col5" class="data row7 col5" >68</td>
#       <td id="T_992fc_row7_col6" class="data row7 col6" ></td>
#     </tr>
#   </tbody>
# </table>
#     8 Predictors classified...
#         1 variables removed since they were ID or low-information variables
#         List of variables removed: ['Unnamed: 0']
# Number of All Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 2 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
